# %%
#a program to draw a barplot to show count for a deck for a dataset

# %%
import seaborn as sns 
import pandas as pd

# %%
data = sns.load_dataset('titanic')

# %%
sns.countplot(x='deck',data=data)
# Out:
# <AxesSubplot:xlabel='deck', ylabel='count'>
