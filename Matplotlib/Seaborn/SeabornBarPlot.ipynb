# %%
#program to draw bar plot of sex against survived for a dataset

# %%
import seaborn as sns 
import pandas as pd

# %%
data = sns.load_dataset('titanic')

# %%
sns.barplot(x='sex',y='survived',data=data)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='survived'>
