# %%
#Python program to create multiple plots.

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
x = [1,3,5]
y = [3,5,6]
x2 = [2,3,6]
y2 = [3,4,7]
x3 = [2,4,6]
y3 = [3,5,7]
fig = plt.figure

# %%
plt.subplot(3,1,1)
plt.plot(x,y)

plt.subplot(3,1,2)
plt.plot(x2,y2)

plt.subplot(3,1,3)
plt.plot(x3,y3)

plt.show()
