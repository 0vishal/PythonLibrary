# %%
#program to display the grid and draw line charts of the closing value of Alphabet Inc. between October 3, 2016 to October 7, 2016.

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('fdata.csv')
print(data)
# Out:
#        Date        Open        High         Low       Close
# 0  03-10-16  774.250000  776.065002  769.500000  772.559998
# 1  04-10-16  776.030029  778.710022  772.890015  776.429993
# 2  05-10-16  779.309998  782.070007  775.650024  776.469971
# 3  06-10-16  779.000000  780.479980  775.539978  776.859985
# 4  07-10-16  779.659973  779.659973  770.750000  775.080017

# %%
plt.xlabel("Date")
plt.ylabel("Close")
plt.title('Closing stock value of Alphabet Inc.')
# Out:
# Text(0.5, 1.0, 'Closing stock value of Alphabet Inc.')

# %%
plt.grid(linestyle='-', linewidth='0.5', color='blue')
plt.plot(data['Date'],data['Close'],color='red')
plt.show()
