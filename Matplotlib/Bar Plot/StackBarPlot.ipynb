# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# importing package
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
  
# create data
data = pd.DataFrame([['A', 3.40022085, 7.70632498, 6.4097905, 10.51648577, 7.5330039, 7.1123587,
12.77792868, 3.44773477], ['B', 11.24811149, 5.03778215, 6.65808464, 12.32220677, 7.45964195, 6.79685302, 7.24578743,
3.69371847], ['C', 3.94253354, 4.74763549, 11.73529246, 4.6465543, 12.9952182, 4.63832778, 11.16849999,
8.56883433], ['D', 4.24409799, 12.71746612, 11.3772169, 9.00514257, 10.47084185, 10.97567589,
3.98287652, 8.80552122]],
                  columns=['People', 'G1','G2','G3','G4','G5','G6','G7','G8'])

  
data.plot(x='People', kind='bar', stacked=True,
        title='Stacked Bar Graph by dataframe')
# Out:
# <AxesSubplot:title={'center':'Stacked Bar Graph by dataframe'}, xlabel='People'>
