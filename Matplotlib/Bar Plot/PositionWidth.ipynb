# %%
#to display a bar chart of the popularity of programming Languages. Specify the position and width of each bar plot

# %%
import pandas as pd 
import numpy as np 
from matplotlib import pyplot as plt 
# %matplotlib inline

# %%
language = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

# %%
plt.bar(language,popularity,align ='center',width=1)
plt.xlabel("Language")
plt.ylabel("Popularity")
# Out:
# Text(0, 0.5, 'Popularity')
