# %%
#program to draw a scatter plot for random 500 x and y coordinates and style it

# %%
import random
import matplotlib.pyplot as plt 
import plotly.express as px
import plotly.graph_objects as go
import numpy as np

# %%
x= [random.triangular() for i in range(500)]
y= [random.triangular() for i in range(500)]

# %%
figure = go.Figure()
figure.add_trace(go.Scatter(x=x, y=y,name="xy",mode='markers',marker=dict(
        size=16,
        color=np.random.randn(500), #set color equal to a variable
        colorscale='Viridis', # one of plotly colorscales
        showscale=True
    )))
figure.show()
